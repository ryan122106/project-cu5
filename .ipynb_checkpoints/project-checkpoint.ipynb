# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder
import joblib

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Mlbb_Heroes.csv')
df.head()
# Out:
#      Name            Title                                         Voice_Line  \
# 0   Aamon   Duke of Shards  It is better to be feared than loved, if you c...
# 1    Akai    Panda Warrior                         Now Akai enters the scene!
# 2  Aldous  Soul Contractor                                       Primary Role
# 3   Alice   Queen of Blood                                   Watch your back!
# 4   Alpha  Blade of Enmity                             Test! Alpha is online.
#
#   Release_Date Primary_Role Secondary_Role      Lane    Hp  Hp_Regen  Mana  \
# 0   2021-10-25     Assassin            NaN   Jungler  2614       8.0   455
# 1         2016         Tank        Support    Roamer  2769       8.4   422
# 2         2018      Fighter            NaN  EXP Lane  2718       9.8   405
# 3         2016         Mage           Tank  EXP Lane  2573       7.2   493
# 4         2017      Fighter            NaN  EXP Lane  2646       7.8   453
#
#    Mana_Regen  Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  \
# 0        21.0         115           0           19           15        250
# 1        12.0         115           0           24           15        260
# 2        18.0         129           0           21           15        260
# 3        18.0         114           0           21           15        240
# 4        31.0         121           0           25           15        260
#
#    Esport_Wins  Esport_Loss
# 0           43           42
# 1          540          524
# 2           95           92
# 3          364          352
# 4           24           33

# %%
df.shape
# Out:
# (114, 18)

# %%
df.isnull().sum()
# Out:
# Name               0
# Title              0
# Voice_Line         0
# Release_Date       0
# Primary_Role       0
# Secondary_Role    84
# Lane               0
# Hp                 0
# Hp_Regen           0
# Mana               0
# Mana_Regen         1
# Phy_Damage         0
# Mag_Damage         0
# Phy_Defence        0
# Mag_Defence        0
# Mov_Speed          0
# Esport_Wins        0
# Esport_Loss        0
# dtype: int64

# %%
df['Secondary_Role'] = df['Secondary_Role'].fillna('None')

# %%
df['Secondary_Role']
# Out:
# 0          None
# 1       Support
# 2          None
# 3          Tank
# 4          None
#          ...
# 109    Marksman
# 110        None
# 111        None
# 112        None
# 113    Assassin
# Name: Secondary_Role, Length: 114, dtype: object

# %%
df.isnull().sum()
# Out:
# Name              0
# Title             0
# Voice_Line        0
# Release_Date      0
# Primary_Role      0
# Secondary_Role    0
# Lane              0
# Hp                0
# Hp_Regen          0
# Mana              0
# Mana_Regen        1
# Phy_Damage        0
# Mag_Damage        0
# Phy_Defence       0
# Mag_Defence       0
# Mov_Speed         0
# Esport_Wins       0
# Esport_Loss       0
# dtype: int64

# %%
df['Mana_Regen'] = pd.to_numeric(df['Mana_Regen'], errors='coerce') # ai ?

# %%
df['Mana_Regen']
# Out:
# 0      21.0
# 1      12.0
# 2      18.0
# 3      18.0
# 4      31.0
#        ...
# 109    15.0
# 110     0.0
# 111    21.0
# 112    20.0
# 113    16.0
# Name: Mana_Regen, Length: 114, dtype: float64

# %%
df.isnull().sum()
# Out:
# Name              0
# Title             0
# Voice_Line        0
# Release_Date      0
# Primary_Role      0
# Secondary_Role    0
# Lane              0
# Hp                0
# Hp_Regen          0
# Mana              0
# Mana_Regen        1
# Phy_Damage        0
# Mag_Damage        0
# Phy_Defence       0
# Mag_Defence       0
# Mov_Speed         0
# Esport_Wins       0
# Esport_Loss       0
# dtype: int64

# %%
df.dtypes
# Out:
# Name               object
# Title              object
# Voice_Line         object
# Release_Date       object
# Primary_Role       object
# Secondary_Role     object
# Lane               object
# Hp                  int64
# Hp_Regen          float64
# Mana                int64
# Mana_Regen        float64
# Phy_Damage          int64
# Mag_Damage          int64
# Phy_Defence         int64
# Mag_Defence         int64
# Mov_Speed           int64
# Esport_Wins         int64
# Esport_Loss         int64
# dtype: object

# %%
plt.hist(df['Hp'], bins=10)
plt.title("HP of Heroes")
plt.xlabel("HP")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.boxplot(y=df['Phy_Damage'], color='lightcoral')
plt.title("Physical Damage - Boxplot")
plt.show()

# %%
df.head()
# Out:
#      Name            Title                                         Voice_Line  \
# 0   Aamon   Duke of Shards  It is better to be feared than loved, if you c...
# 1    Akai    Panda Warrior                         Now Akai enters the scene!
# 2  Aldous  Soul Contractor                                       Primary Role
# 3   Alice   Queen of Blood                                   Watch your back!
# 4   Alpha  Blade of Enmity                             Test! Alpha is online.
#
#   Release_Date Primary_Role Secondary_Role      Lane    Hp  Hp_Regen  Mana  \
# 0   2021-10-25     Assassin           None   Jungler  2614       8.0   455
# 1         2016         Tank        Support    Roamer  2769       8.4   422
# 2         2018      Fighter           None  EXP Lane  2718       9.8   405
# 3         2016         Mage           Tank  EXP Lane  2573       7.2   493
# 4         2017      Fighter           None  EXP Lane  2646       7.8   453
#
#    Mana_Regen  Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  \
# 0        21.0         115           0           19           15        250
# 1        12.0         115           0           24           15        260
# 2        18.0         129           0           21           15        260
# 3        18.0         114           0           21           15        240
# 4        31.0         121           0           25           15        260
#
#    Esport_Wins  Esport_Loss
# 0           43           42
# 1          540          524
# 2           95           92
# 3          364          352
# 4           24           33

# %%
numeric_cols = ['Hp','Hp_Regen','Mana','Mana_Regen','Phy_Damage','Mag_Damage','Phy_Defence','Mag_Defence','Mov_Speed']
X = df[numeric_cols]
y = df['Primary_Role']

# %%
df.Primary_Role.value_counts()
# Out:
# Primary_Role
# Fighter     33
# Mage        25
# Marksman    18
# Tank        16
# Assassin    13
# Support      9
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.heatmap(df[numeric_cols].corr(), cmap='coolwarm')
plt.title("Hero Attributes")
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# ai

# %%
X
# Out:
#        Hp  Hp_Regen  Mana  Mana_Regen  Phy_Damage  Mag_Damage  Phy_Defence  \
# 0    2614       8.0   455        21.0         115           0           19
# 1    2769       8.4   422        12.0         115           0           24
# 2    2718       9.8   405        18.0         129           0           21
# 3    2573       7.2   493        18.0         114           0           21
# 4    2646       7.8   453        31.0         121           0           25
# ..    ...       ...   ...         ...         ...         ...          ...
# 109  2570       7.2   438        15.0         100           0           22
# 110  2698      11.8     0         0.0         129           0           21
# 111  2651       7.2   510        21.0         115           0           19
# 112  2401       6.8   490        20.0         107           0           15
# 113  2689       7.0   405        16.0         123           0           25
#
#      Mag_Defence  Mov_Speed
# 0             15        250
# 1             15        260
# 2             15        260
# 3             15        240
# 4             15        260
# ..           ...        ...
# 109           15        250
# 110           15        245
# 111           15        255
# 112           15        240
# 113           15        265
#
# [114 rows x 9 columns]

# %%
y
# Out:
# 0      Assassin
# 1          Tank
# 2       Fighter
# 3          Mage
# 4       Fighter
#          ...
# 109    Assassin
# 110     Fighter
# 111        Mage
# 112        Mage
# 113     Fighter
# Name: Primary_Role, Length: 114, dtype: object

# %%
# from sklearn.preprocessing import MultiLabelBinarizer
# mlb = MultiLabelBinarizer()
# y_ = mlb.fit_transform(y)

# %%
le_role = LabelEncoder()
y_encoded = le_role.fit_transform(y)
# ai

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# y_train_enc

# %%
y_pred = model.predict(X_test_scaled)
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')
print("Accuracy:", acc)
print("F1 Score:", f1)
print(classification_report(y_test, y_pred))
# ai
# Out:
# Accuracy: 0.8285714285714286
# F1 Score: 0.8189786059351277
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         4
#            1       0.75      0.82      0.78        11
#            2       1.00      1.00      1.00         7
#            3       0.86      0.86      0.86         7
#            4       1.00      1.00      1.00         1
#            5       0.67      0.40      0.50         5
#
#     accuracy                           0.83        35
#    macro avg       0.85      0.85      0.84        35
# weighted avg       0.82      0.83      0.82        35

# %%
joblib.dump(le_role, "hero_encoder.pkl") # ai
joblib.dump(model, "mlbb_hero_model.pkl")
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
role_to_heroes = df.groupby('Primary_Role')['Name'].apply(list).to_dict()

# %%
# ! pip install gradio

# %%
print(df['Hp'].min())
print(df['Hp_Regen'].min())
print(df['Mana'].min())
print(df['Mana_Regen'].min())
print(df['Phy_Damage'].min())
print(df['Mag_Damage'].min())
print(df['Phy_Defence'].min())
print(df['Mag_Defence'].min())
print(df['Mov_Speed'].min())
# Out:
# 918
# 3.8
# 0
# 0.0
# 90
# 0
# 10
# 10
# 240

# %%
print(df['Hp'].max())
print(df['Hp_Regen'].max())
print(df['Mana'].max())
print(df['Mana_Regen'].max())
print(df['Phy_Damage'].max())
print(df['Mag_Damage'].max())
print(df['Phy_Defence'].max())
print(df['Mag_Defence'].max())
print(df['Mov_Speed'].max())
# Out:
# 2909
# 18.4
# 750
# 240.0
# 140
# 0
# 27
# 15
# 270

# %%
import gradio as gr
import numpy as np
import joblib

model = joblib.load("mlbb_hero_model.pkl")
scaler = joblib.load("scaler.pkl")
le_role = joblib.load("hero_encoder.pkl")

def predict_role_and_heroes(Hp, Hp_Regen, Mana, Mana_Regen, Phy_Damage, Mag_Damage, Phy_Defence, Mag_Defence, Mov_Speed):
    user_input = np.array([[Hp, Hp_Regen, Mana, Mana_Regen, Phy_Damage, Mag_Damage, Phy_Defence, Mag_Defence, Mov_Speed]])
    user_input_scaled = scaler.transform(user_input)
    role_encoded = model.predict(user_input_scaled)
    role_name = le_role.inverse_transform(role_encoded)[0]
    heroes = ", ".join(role_to_heroes[role_name]) # ai
    return f"Your suitable role: {role_name}\nHeroes in this role: {heroes}"

app = gr.Interface(
    fn=predict_role_and_heroes,
    inputs=[
        gr.Slider(918, 2909, step=1, label="HP"),
        gr.Slider(3.8, 18.4, step=0.1, label="HP Regen"),
        gr.Slider(0, 750, step=1, label="Mana"),
        gr.Slider(0, 31, step=1, label="Mana Regen"),
        gr.Slider(90, 140, step=1, label="Physical Damage"),
        gr.Slider(0, 150, step=1, label="Magic Damage"),
        gr.Slider(10, 27, step=1, label="Physical Defence"),
        gr.Slider(10, 25, step=1, label="Magic Defence"),
        gr.Slider(240, 270, step=1, label="Movement Speed"),
    ],
    outputs=gr.Textbox(label="Role & Heroes", lines=4),
    title="MLBB Role Predictor with Hero Names"
)

app.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
df.columns

# %%
df.head()

# %%
df['Name'].value_counts()
