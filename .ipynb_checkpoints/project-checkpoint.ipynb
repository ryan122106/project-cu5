# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Mlbb_Heroes.csv')
df
# Out:
#             Name             Title  \
# 0          Aamon    Duke of Shards
# 1           Akai     Panda Warrior
# 2         Aldous   Soul Contractor
# 3          Alice    Queen of Blood
# 4          Alpha   Blade of Enmity
# ..           ...               ...
# 109  Yi_Sun-Shin   Paenlong Legend
# 110     Yu_Zhong      Black Dragon
# 111          Yve       Astrowarden
# 112        Zhask  Planes Dominator
# 113       Zilong   Spear of Dragon
#
#                                             Voice_Line Release_Date  \
# 0    It is better to be feared than loved, if you c...   2021-10-25
# 1                           Now Akai enters the scene!         2016
# 2                                         Primary Role         2018
# 3                                     Watch your back!         2016
# 4                               Test! Alpha is online.         2017
# ..                                                 ...          ...
# 109                                     Secondary Role         2017
# 110  I would rather betray the world, than let the ...   2020-06-19
# 111  Among the planes exists the equilibrium, which...   2021-02-12
# 112                    Grovel before your King, human!   2017-11-27
# 113                            The Dragonborn is back!         2016
#
#     Primary_Role Secondary_Role       Lane    Hp  Hp_Regen  Mana  Mana_Regen  \
# 0       Assassin            NaN    Jungler  2614       8.0   455        21.0
# 1           Tank        Support     Roamer  2769       8.4   422        12.0
# 2        Fighter            NaN   EXP Lane  2718       9.8   405        18.0
# 3           Mage           Tank   EXP Lane  2573       7.2   493        18.0
# 4        Fighter            NaN   EXP Lane  2646       7.8   453        31.0
# ..           ...            ...        ...   ...       ...   ...         ...
# 109     Assassin       Marksman    Jungler  2570       7.2   438        15.0
# 110      Fighter            NaN   EXP Lane  2698      11.8     0         0.0
# 111         Mage            NaN        Mid  2651       7.2   510        21.0
# 112         Mage            NaN        Mid  2401       6.8   490        20.0
# 113      Fighter       Assassin  Gold Lane  2689       7.0   405        16.0
#
#      Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  \
# 0           115           0           19           15        250           43
# 1           115           0           24           15        260          540
# 2           129           0           21           15        260           95
# 3           114           0           21           15        240          364
# 4           121           0           25           15        260           24
# ..          ...         ...          ...          ...        ...          ...
# 109         100           0           22           15        250          443
# 110         129           0           21           15        245          550
# 111         115           0           19           15        255          834
# 112         107           0           15           15        240           37
# 113         123           0           25           15        265            5
#
#      Esport_Loss
# 0             42
# 1            524
# 2             92
# 3            352
# 4             33
# ..           ...
# 109          383
# 110          594
# 111          722
# 112           46
# 113           23
#
# [114 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# Name               0
# Title              0
# Voice_Line         0
# Release_Date       0
# Primary_Role       0
# Secondary_Role    84
# Lane               0
# Hp                 0
# Hp_Regen           0
# Mana               0
# Mana_Regen         1
# Phy_Damage         0
# Mag_Damage         0
# Phy_Defence        0
# Mag_Defence        0
# Mov_Speed          0
# Esport_Wins        0
# Esport_Loss        0
# dtype: int64

# %%
df['Secondary_Role'] = df['Secondary_Role'].fillna('None')

# %%
df['Secondary_Role']
# Out:
# 0          None
# 1       Support
# 2          None
# 3          Tank
# 4          None
#          ...
# 109    Marksman
# 110        None
# 111        None
# 112        None
# 113    Assassin
# Name: Secondary_Role, Length: 114, dtype: object

# %%
df.isnull().sum()
# Out:
# Name              0
# Title             0
# Voice_Line        0
# Release_Date      0
# Primary_Role      0
# Secondary_Role    0
# Lane              0
# Hp                0
# Hp_Regen          0
# Mana              0
# Mana_Regen        1
# Phy_Damage        0
# Mag_Damage        0
# Phy_Defence       0
# Mag_Defence       0
# Mov_Speed         0
# Esport_Wins       0
# Esport_Loss       0
# dtype: int64

# %%
df['Mana_Regen'] = df['Mana_Regen'].fillna('None')

# %%
df['Mana_Regen']
# Out:
# 0      21.0
# 1      12.0
# 2      18.0
# 3      18.0
# 4      31.0
#        ...
# 109    15.0
# 110     0.0
# 111    21.0
# 112    20.0
# 113    16.0
# Name: Mana_Regen, Length: 114, dtype: object

# %%
df.isnull().sum()
# Out:
# Name              0
# Title             0
# Voice_Line        0
# Release_Date      0
# Primary_Role      0
# Secondary_Role    0
# Lane              0
# Hp                0
# Hp_Regen          0
# Mana              0
# Mana_Regen        0
# Phy_Damage        0
# Mag_Damage        0
# Phy_Defence       0
# Mag_Defence       0
# Mov_Speed         0
# Esport_Wins       0
# Esport_Loss       0
# dtype: int64

# %%
df.dtypes
# Out:
# Name               object
# Title              object
# Voice_Line         object
# Release_Date       object
# Primary_Role       object
# Secondary_Role     object
# Lane               object
# Hp                  int64
# Hp_Regen          float64
# Mana                int64
# Mana_Regen         object
# Phy_Damage          int64
# Mag_Damage          int64
# Phy_Defence         int64
# Mag_Defence         int64
# Mov_Speed           int64
# Esport_Wins         int64
# Esport_Loss         int64
# dtype: object

# %%
numeric_cols = ['Hp','Hp_Regen','Mana','Mana_Regen','Phy_Damage','Mag_Damage','Phy_Defence','Mag_Defence','Mov_Speed']

x = df[numeric_cols]
y = df['Name']

# %%
x
# Out:
#        Hp  Hp_Regen  Mana  Mana_Regen  Phy_Damage  Mag_Damage  Phy_Defence  \
# 0    2614       8.0   455        21.0         115           0           19
# 1    2769       8.4   422        12.0         115           0           24
# 2    2718       9.8   405        18.0         129           0           21
# 3    2573       7.2   493        18.0         114           0           21
# 4    2646       7.8   453        31.0         121           0           25
# ..    ...       ...   ...         ...         ...         ...          ...
# 109  2570       7.2   438        15.0         100           0           22
# 110  2698      11.8     0         0.0         129           0           21
# 111  2651       7.2   510        21.0         115           0           19
# 112  2401       6.8   490        20.0         107           0           15
# 113  2689       7.0   405        16.0         123           0           25
#
#      Mag_Defence  Mov_Speed
# 0             15        250
# 1             15        260
# 2             15        260
# 3             15        240
# 4             15        260
# ..           ...        ...
# 109           15        250
# 110           15        245
# 111           15        255
# 112           15        240
# 113           15        265
#
# [114 rows x 9 columns]

# %%
y
# Out:
# 0            Aamon
# 1             Akai
# 2           Aldous
# 3            Alice
# 4            Alpha
#           ...
# 109    Yi_Sun-Shin
# 110       Yu_Zhong
# 111            Yve
# 112          Zhask
# 113         Zilong
# Name: Name, Length: 114, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
joblib.dump(model, "mlbb_hero_model.pkl")
joblib.dump(scaler, "scaler.pkl")
print("Model and scaler saved!")
# Out:
# Model and scaler saved!

# %%
! pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\piriyan\anaconda3\lib\site-packages (6.2.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (0.128.0)
# Requirement already satisfied: ffmpy in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.0.2 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (2.0.2)
# Requirement already satisfied: groovy~=0.1 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (1.2.3)
# Requirement already satisfied: jinja2<4.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (3.11.5)
# Requirement already satisfied: packaging in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (10.3.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (2.12.3)
# Requirement already satisfied: pydub in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (0.0.21)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (0.17.4)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\piriyan\anaconda3\lib\site-packages (from gradio) (0.40.0)
# Requirement already satisfied: fsspec in c:\users\piriyan\anaconda3\lib\site-packages (from gradio-client==2.0.2->gradio) (2024.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\piriyan\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\piriyan\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\piriyan\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in c:\users\piriyan\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\piriyan\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\piriyan\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\piriyan\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.13.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\piriyan\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\piriyan\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\piriyan\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.66.4)
# Requirement already satisfied: typer-slim in c:\users\piriyan\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (0.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\piriyan\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\piriyan\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\piriyan\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\piriyan\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\piriyan\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\piriyan\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\piriyan\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: rich>=10.11.0 in c:\users\piriyan\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.3.5)
# Requirement already satisfied: colorama in c:\users\piriyan\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\piriyan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\piriyan\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\piriyan\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\piriyan\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
print(df['Hp'].min())
print(df['Hp_Regen'].min())
print(df['Mana'].min())
print(df['Mana_Regen'].min())
print(df['Phy_Damage'].min())
print(df['Mag_Damage'].min())
print(df['Phy_Defence'].min())
print(df['Mag_Defence'].min())
print(df['Mov_Speed'].min())
# Out:
# 918
# 3.8
# 0
# 0.0
# 90
# 0
# 10
# 10
# 240

# %%
print(df['Hp'].max())
print(df['Hp_Regen'].max())
print(df['Mana'].max())
print(df['Mana_Regen'].max())
print(df['Phy_Damage'].max())
print(df['Mag_Damage'].max())
print(df['Phy_Defence'].max())
print(df['Mag_Defence'].max())
print(df['Mov_Speed'].max())
# Out:
# 2909
# 18.4
# 750
# 240.0
# 140
# 0
# 27
# 15
# 270

# %%
import gradio as gr
import numpy as np
import joblib

model = joblib.load("mlbb_hero_model.pkl")
scaler = joblib.load("scaler.pkl")

def predict_hero(Hp, Hp_Regen, Mana, Mana_Regen, Phy_Damage, Mag_Damage, Phy_Defence, Mag_Defence, Mov_Speed):
    user_input = np.array([[Hp, Hp_Regen, Mana, Mana_Regen, Phy_Damage, Mag_Damage, Phy_Defence, Mag_Defence, Mov_Speed]])
    user_input_scaled = scaler.transform(user_input)
    hero_name = model.predict(user_input_scaled)[0]
    return f"Recommended Hero: {hero_name}"
app = gr.Interface(
    fn=predict_hero,
     inputs=[
        gr.Slider(918, 2909, step=1, label="HP", info="Low ~1000, Medium ~2000, High ~2900"),
        gr.Slider(3.8, 18.4, step=0.1, label="HP Regen", info="Low ~4, Medium ~10, High ~18"),
        gr.Slider(0, 750, step=1, label="Mana", info="Low 0, Medium ~400, High ~750"),
        gr.Slider(0, 31, step=1, label="Mana Regen", info="Low 0, Medium ~15, High ~30"),
        gr.Slider(90, 140, step=1, label="Physical Damage", info="Low ~50, Medium ~100, High ~140"),
        gr.Slider(0, 150, step=1, label="Magic Damage", info="Low 0, Medium ~75, High ~150"),
        gr.Slider(10, 27, step=1, label="Physical Defence", info="Low ~10, Medium ~18, High ~27"),
        gr.Slider(10, 25, step=1, label="Magic Defence", info="Low 0, Medium ~12, High ~25"),
        gr.Slider(240, 270, step=1, label="Movement Speed", info="Low 240, Medium 255, High 270"),
    ],
    outputs=gr.Textbox(label="Your Hero"),
    title="Choose your suitable hero for your mlbb",
)

app.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7925
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7925/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
df.columns
# Out:
# Index(['Name', 'Title', 'Voice_Line', 'Release_Date', 'Primary_Role',
#        'Secondary_Role', 'Lane', 'Hp', 'Hp_Regen', 'Mana', 'Mana_Regen',
#        'Phy_Damage', 'Mag_Damage', 'Phy_Defence', 'Mag_Defence', 'Mov_Speed',
#        'Esport_Wins', 'Esport_Loss'],
#       dtype='object')

# %%
df.head()
# Out:
#      Name            Title                                         Voice_Line  \
# 0   Aamon   Duke of Shards  It is better to be feared than loved, if you c...
# 1    Akai    Panda Warrior                         Now Akai enters the scene!
# 2  Aldous  Soul Contractor                                       Primary Role
# 3   Alice   Queen of Blood                                   Watch your back!
# 4   Alpha  Blade of Enmity                             Test! Alpha is online.
#
#   Release_Date Primary_Role Secondary_Role      Lane    Hp  Hp_Regen  Mana  \
# 0   2021-10-25     Assassin            NaN   Jungler  2614       8.0   455
# 1         2016         Tank        Support    Roamer  2769       8.4   422
# 2         2018      Fighter            NaN  EXP Lane  2718       9.8   405
# 3         2016         Mage           Tank  EXP Lane  2573       7.2   493
# 4         2017      Fighter            NaN  EXP Lane  2646       7.8   453
#
#    Mana_Regen  Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  \
# 0        21.0         115           0           19           15        250
# 1        12.0         115           0           24           15        260
# 2        18.0         129           0           21           15        260
# 3        18.0         114           0           21           15        240
# 4        31.0         121           0           25           15        260
#
#    Esport_Wins  Esport_Loss
# 0           43           42
# 1          540          524
# 2           95           92
# 3          364          352
# 4           24           33

# %%
df['Name'].value_counts()
# Out:
# Name
# Aamon         1
# Nana          1
# Miya          1
# Minsitthar    1
# Minotaur      1
#              ..
# Fanny         1
# Eudora        1
# Estes         1
# Edith         1
# Zilong        1
# Name: count, Length: 114, dtype: int64
